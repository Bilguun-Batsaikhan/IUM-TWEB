# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
club = pd.read_csv('/Users/alexagliuzza/Desktop/IUM-TWEB/Solution/csv/clubs.csv')

# %% [markdown]
# ### Step 1: Data Understanding ###
# + Dataframe shape
# + head
# + dtypes
# + describe

# %%
club.shape
# Out:
# (426, 16)

# %%
club.head(20)
# Out:
#     club_id            club_code                                  name  \
# 0       105      sv-darmstadt-98      Sportverein Darmstadt 1898 e. V.
# 1     11127    ural-ekaterinburg                 FK Ural Yekaterinburg
# 2       114    besiktas-istanbul             Beşiktaş Jimnastik Kulübü
# 3        12               as-rom            Associazione Sportiva Roma
# 4       148    tottenham-hotspur       Tottenham Hotspur Football Club
# 5       157             kaa-gent  Koninklijke Atletiek Associatie Gent
# 6      1894          hvidovre-if               Hvidovre Idrætsforening
# 7       190        fc-kopenhagen               Football Club København
# 8       192     roda-jc-kerkrade                      Roda JC Kerkrade
# 9     19789     yeni-malatyaspor                      Yeni Malatyaspor
# 10     2079            veria-nps                             Veria NPS
# 11    21957         ao-platanias                          AO Platanias
# 12     2414           ac-horsens                            AC Horsens
# 13     2457       belenenses-sad                                 B SAD
# 14     2578      st-johnstone-fc         Saint Johnstone Football Club
# 15     2727  oud-heverlee-leuven                   Oud-Heverlee Leuven
# 16    28643     waasland-beveren                            SK Beveren
# 17     2990    academica-coimbra                     Académica Coimbra
# 18     3057     standard-luttich          Royal Standard Club de Liège
# 19     3690       ska-khabarovsk                        SKA Khabarovsk
#
#    domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                       L1                 NaN          30         26.4
# 1                      RU1                 NaN          25         28.2
# 2                      TR1                 NaN          32         27.4
# 3                      IT1                 NaN          26         27.4
# 4                      GB1                 NaN          29         26.2
# 5                      BE1                 NaN          25         25.7
# 6                      DK1                 NaN          30         27.1
# 7                      DK1                 NaN          28         25.4
# 8                      NL1                 NaN          25         24.0
# 9                      TR1                 NaN          10         22.9
# 10                     GR1                 NaN          29         24.3
# 11                     GR1                 NaN           0          NaN
# 12                     DK1                 NaN          19         25.1
# 13                     PO1                 NaN          25         24.2
# 14                     SC1                 NaN          28         26.9
# 15                     BE1                 NaN          27         24.9
# 16                     BE1                 NaN          27         26.8
# 17                     PO1                 NaN          26         25.2
# 18                     BE1                 NaN          26         24.6
# 19                     RU1                 NaN          27         25.7
#
#     foreigners_number  foreigners_percentage  national_team_players  \
# 0                  11                   36.7                      1
# 1                  13                   52.0                      5
# 2                  16                   50.0                     13
# 3                  17                   65.4                     17
# 4                  21                   72.4                     22
# 5                  13                   52.0                      8
# 6                   4                   13.3                      2
# 7                  14                   50.0                      8
# 8                   9                   36.0                      0
# 9                   1                   10.0                      0
# 10                  4                   13.8                      0
# 11                  0                    NaN                      0
# 12                  9                   47.4                      4
# 13                 13                   52.0                      4
# 14                 16                   57.1                      3
# 15                 16                   59.3                      3
# 16                 16                   59.3                      3
# 17                  6                   23.1                      0
# 18                 16                   61.5                     10
# 19                  4                   14.8                      0
#
#                        stadium_name  stadium_seats net_transfer_record  \
# 0    Merck-Stadion am Böllenfalltor          17810             €-1.60m
# 1               Yekaterinburg Arena          23000              €-770k
# 2                   Tüpraş Stadyumu          42590            €-14.50m
# 3                  Olimpico di Roma          73261            +€65.20m
# 4         Tottenham Hotspur Stadium          62062           €-130.40m
# 5                    Ghelamco Arena          19999             +€2.52m
# 6             PRO VENTILATION Arena          12000              +€335k
# 7                            Parken          38065             +€9.63m
# 8          Parkstad Limburg Stadion          19979             +€1.30m
# 9             Yeni Malatya Stadyumu          25745              +€778k
# 10           Dimotiko Stadio Verias           6350                 +-0
# 11        Dimotiko Gipedo Perivolia           3700                 +-0
# 12          Nordstern Arena Horsens          10400                 +-0
# 13        Estádio Nacional do Jamor          37593             +€1.80m
# 14                   McDiarmid Park          10696                 +-0
# 15  King Power at Den Dreef Stadion          10020                 +-0
# 16                 Freethielstadion          13290              €-350k
# 17        Estádio Cidade de Coimbra          29744              +€150k
# 18         Maurice Dufrasne Stadion          27670             +€1.30m
# 19                    Lenin Stadion          15200               €-93k
#
#     coach_name  last_season                                                url
# 0          NaN         2023  https://www.transfermarkt.co.uk/sv-darmstadt-9...
# 1          NaN         2023  https://www.transfermarkt.co.uk/ural-ekaterinb...
# 2          NaN         2023  https://www.transfermarkt.co.uk/besiktas-istan...
# 3          NaN         2023  https://www.transfermarkt.co.uk/as-rom/startse...
# 4          NaN         2023  https://www.transfermarkt.co.uk/tottenham-hots...
# 5          NaN         2023  https://www.transfermarkt.co.uk/kaa-gent/start...
# 6          NaN         2023  https://www.transfermarkt.co.uk/hvidovre-if/st...
# 7          NaN         2023  https://www.transfermarkt.co.uk/fc-kopenhagen/...
# 8          NaN         2017  https://www.transfermarkt.co.uk/roda-jc-kerkra...
# 9          NaN         2021  https://www.transfermarkt.co.uk/yeni-malatyasp...
# 10         NaN         2016  https://www.transfermarkt.co.uk/veria-nps/star...
# 11         NaN         2017  https://www.transfermarkt.co.uk/ao-platanias/s...
# 12         NaN         2022  https://www.transfermarkt.co.uk/ac-horsens/sta...
# 13         NaN         2021  https://www.transfermarkt.co.uk/belenenses-sad...
# 14         NaN         2023  https://www.transfermarkt.co.uk/st-johnstone-f...
# 15         NaN         2023  https://www.transfermarkt.co.uk/oud-heverlee-l...
# 16         NaN         2020  https://www.transfermarkt.co.uk/waasland-bever...
# 17         NaN         2015  https://www.transfermarkt.co.uk/academica-coim...
# 18         NaN         2023  https://www.transfermarkt.co.uk/standard-lutti...
# 19         NaN         2017  https://www.transfermarkt.co.uk/ska-khabarovsk...

# %%
club.columns
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'last_season',
#        'url'],
#       dtype='object')

# %%
club.dtypes
# Out:
# club_id                      int64
# club_code                   object
# name                        object
# domestic_competition_id     object
# total_market_value         float64
# squad_size                   int64
# average_age                float64
# foreigners_number            int64
# foreigners_percentage      float64
# national_team_players        int64
# stadium_name                object
# stadium_seats                int64
# net_transfer_record         object
# coach_name                 float64
# last_season                  int64
# url                         object
# dtype: object

# %% [markdown]
# + club_id: A unique identifier for each club.
# + club_code: A code or abbreviation representing each club.
# + name: The complete name of the club.
# + domestic_competition_id: A unique identifier for each competition.
# + total_market_value: This value is null for every column.
# + squad_size: It is the number of players for every club.
# + average_age: It is the mean age of players for every club.
# + foreigners_number: It is the number of foreign players for every club.
# + foreigners_percentage: It is the percentage of foreign players for every club.
# + national_team_players: It is the number of players for every club that also play for a national team.
# + stadium_name: This is the name of the stadium for every club.
# + stadium_seats: This is the number of seats in the stadium for every club.
# + net_transfer_record: Probably the transfer record.
# + coach_name: This value is null for every column.
# + last_season: The year of the last games played by that club.
# + url: The URL link to access more information about the club, potentially leading to details such as schedules, results, and standings.

# %%
club.describe()
# Out:
#             club_id  total_market_value  squad_size  average_age  \
# count    426.000000                 0.0  426.000000   388.000000
# mean    5314.525822                 NaN   24.403756    25.704639
# std    11752.013818                 NaN    8.817703     1.596598
# min        3.000000                 NaN    0.000000    18.300000
# 25%      421.000000                 NaN   24.000000    24.700000
# 50%     1139.500000                 NaN   27.000000    25.700000
# 75%     3415.750000                 NaN   29.000000    26.900000
# max    83678.000000                 NaN   41.000000    29.700000
#
#        foreigners_number  foreigners_percentage  national_team_players  \
# count         426.000000             379.000000             426.000000
# mean           10.983568              45.227968               4.788732
# std             6.726748              19.941673               5.083071
# min             0.000000               2.400000               0.000000
# 25%             6.000000              30.800000               1.000000
# 50%            12.000000              46.700000               3.000000
# 75%            16.000000              58.000000               7.000000
# max            31.000000             100.000000              22.000000
#
#        stadium_seats  coach_name  last_season
# count     426.000000         0.0   426.000000
# mean    24284.410798         NaN  2020.830986
# std     17132.848095         NaN     3.207283
# min         0.000000         NaN  2012.000000
# 25%     11024.500000         NaN  2019.000000
# 50%     20046.000000         NaN  2023.000000
# 75%     32798.000000         NaN  2023.000000
# max     81365.000000         NaN  2023.000000

# %% [markdown]
# ### Step 2: Data Preperation ###
# + Dropping irrelevant columns and rows
# + Identifying duplicated columns
# + Feature Creation

# %%
club.isna().sum()
# Out:
# club_id                      0
# club_code                    0
# name                         0
# domestic_competition_id      0
# total_market_value         426
# squad_size                   0
# average_age                 38
# foreigners_number            0
# foreigners_percentage       47
# national_team_players        0
# stadium_name                 0
# stadium_seats                0
# net_transfer_record          0
# coach_name                 426
# last_season                  0
# url                          0
# dtype: int64

# %%
mean_columns = club['average_age'].mean()
club['average_age'].fillna(mean_columns, inplace=True)
club['average_age'].isna().sum()
# Out:
# /var/folders/rr/82gtjrmj0wxf33vcvnq5y9l00000gn/T/ipykernel_4469/895119531.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   club['average_age'].fillna(mean_columns, inplace=True)
# 0

# %%
mean_columns = club['foreigners_percentage'].mean()
club['foreigners_percentage'].fillna(mean_columns, inplace=True)
club['foreigners_percentage'].isna().sum()
# Out:
# /var/folders/rr/82gtjrmj0wxf33vcvnq5y9l00000gn/T/ipykernel_4469/348542659.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   club['foreigners_percentage'].fillna(mean_columns, inplace=True)
# 0

# %%
new_club = club[['club_id', 'club_code', 'name', 'domestic_competition_id',
       'squad_size', 'average_age', 'foreigners_number',
       'foreigners_percentage', 'national_team_players', 'stadium_name',
       'stadium_seats', 'net_transfer_record', 'last_season']].copy()

# %%
new_club.shape
# Out:
# (426, 13)

# %%
new_club.loc[new_club.duplicated()]
# Out:
# Empty DataFrame
# Columns: [club_id, club_code, name, domestic_competition_id, squad_size, average_age, foreigners_number, foreigners_percentage, national_team_players, stadium_name, stadium_seats, net_transfer_record, last_season]
# Index: []

# %%
new_club.loc[new_club.duplicated(subset=['club_code'])]
# Out:
# Empty DataFrame
# Columns: [club_id, club_code, name, domestic_competition_id, squad_size, average_age, foreigners_number, foreigners_percentage, national_team_players, stadium_name, stadium_seats, net_transfer_record, last_season]
# Index: []

# %%
new_club.loc[new_club.duplicated(subset=['name'])]
# Out:
# Empty DataFrame
# Columns: [club_id, club_code, name, domestic_competition_id, squad_size, average_age, foreigners_number, foreigners_percentage, national_team_players, stadium_name, stadium_seats, net_transfer_record, last_season]
# Index: []

# %%
new_club.loc[new_club.duplicated(subset=['stadium_name'])]
# Out:
#      club_id              club_code  \
# 57     83678          metal-kharkiv
# 105    41274         beerschot-v-a-
# 169    10690          zorya-lugansk
# 205      354            kv-mechelen
# 263      820  genclerbirligi-ankara
# 279      398              lazio-rom
# 305     3840        adana-demirspor
# 306      430             ac-florenz
# 309        5             ac-mailand
# 312    60949              volos-nps
# 314     7775              hatayspor
# 334      441        apollon-smyrnis
# 340      660       shakhtar-donetsk
# 345      862          chievo-verona
# 358    41201             pfk-tambov
# 360      520          cercle-brugge
# 367     1038        sampdoria-genua
#
#                                             name domestic_competition_id  \
# 57                              Metalist Kharkiv                    UKR1
# 105                               Beerschot V.A.                     BE1
# 169                             FK Zarya Lugansk                    UKR1
# 205  Yellow-Red Koninklijke Voetbalclub Mechelen                     BE1
# 263                        Genclerbirligi Ankara                     TR1
# 279                Società Sportiva Lazio S.p.A.                     IT1
# 305                       Adana Demirspor Kulübü                     TR1
# 306               Associazione Calcio Fiorentina                     IT1
# 309                    Associazione Calcio Milan                     IT1
# 312             Neos Podosferikos Syllogos Volou                     GR1
# 314                      Hatayspor Futbol Kulübü                     TR1
# 334                              Apollon Smyrnis                     GR1
# 340                          FC Shakhtar Donetsk                    UKR1
# 345                                Chievo Verona                     IT1
# 358                           PFK Tambov (-2021)                     RU1
# 360    Cercle Brugge Koninklijke Sportvereniging                     BE1
# 367                                 UC Sampdoria                     IT1
#
#      squad_size  average_age  foreigners_number  foreigners_percentage  \
# 57           25    26.100000                  7              28.000000
# 105          26    23.900000                 12              46.200000
# 169          31    23.900000                  5              16.100000
# 205          27    24.800000                  9              33.300000
# 263          34    26.100000                 10              29.400000
# 279          29    27.400000                 17              58.600000
# 305          31    27.500000                 16              51.600000
# 306          31    25.200000                 16              51.600000
# 309          29    26.300000                 22              75.900000
# 312          29    26.400000                 16              55.200000
# 314          30    24.900000                 15              50.000000
# 334          27    27.300000                 15              55.600000
# 340          34    24.100000                 11              32.400000
# 345           0    25.704639                  0              45.227968
# 358           0    25.704639                  0              45.227968
# 360          24    23.600000                 15              62.500000
# 367          33    24.300000                  5              15.600000
#
#      national_team_players           stadium_name  stadium_seats  \
# 57                       0               Avangard          10640
# 105                      2      Olympisch Stadion          12771
# 169                      2      Livyi Bereg Arena           4700
# 205                      2           AFAS Stadion          16672
# 263                      1       Eryaman Stadyumu          20560
# 279                     11       Olimpico di Roma          73261
# 305                      7    Yeni Adana Stadyumu          33000
# 306                     10        Artemio Franchi          43147
# 309                     15        Giuseppe Meazza          75923
# 312                      1   Panthessaliko Stadio          22700
# 314                      6        Mersin Stadyumu          25000
# 334                      0    Stadio Neas Smyrnis          11700
# 340                     16             Arena Lviv          34725
# 345                      0  Marcantonio Bentegodi          31045
# 358                      0         Mordovia Arena          44149
# 360                      4    Jan-Breydel-Stadion          29062
# 367                      4         Luigi Ferraris          36348
#
#     net_transfer_record  last_season
# 57               +€300k         2022
# 105              +€395k         2021
# 169             +€1.75m         2023
# 205              €-900k         2023
# 263              +€195k         2020
# 279            +€10.44m         2023
# 305              +€750k         2023
# 306            +€17.42m         2023
# 309            €-47.40m         2023
# 312                 +-0         2023
# 314             +€7.19m         2023
# 334                 +-0         2021
# 340             €-2.05m         2023
# 345                 +-0         2018
# 358                 +-0         2020
# 360            +€12.00m         2023
# 367             +€1.75m         2022

# %%
new_club.columns
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id', 'squad_size',
#        'average_age', 'foreigners_number', 'foreigners_percentage',
#        'national_team_players', 'stadium_name', 'stadium_seats',
#        'net_transfer_record', 'last_season'],
#       dtype='object')

# %% [markdown]
# ### Step 3: Feature Understanding ###
# + My questions
#        + How many clubs plays for every competitions?
#        + How many clubs are still active for every competitions?
#        + How are the values distributed? Are there any outliers?
#        + How are the values distributed for club organized by competitions?
# + Plotting Feature Distributions
#        + Histogram
#        + Bar Chart
#        + Boxplot
#        + Scatterplot
#        + HeatMap

# %%
new_club['domestic_competition_id'].value_counts()
# Out:
# domestic_competition_id
# TR1     40
# IT1     37
# GB1     36
# FR1     35
# UKR1    34
# PO1     33
# RU1     32
# ES1     32
# L1      29
# NL1     28
# GR1     28
# BE1     26
# DK1     20
# SC1     16
# Name: count, dtype: int64

# %%
ax = new_club['domestic_competition_id'].value_counts().plot(kind='bar',
                                                             title = 'Count club for every domestic competition all time',
                                                             color = 'skyblue',
                                                             edgecolor='black')
plt.xticks(rotation=45, ha='right')
ax.set(xlabel='Domestic ID competitions')
ax.set(ylabel='Number of Club all time')
# Out:
# [Text(0, 0.5, 'Number of Club all time')]

# %%
new_club.loc[new_club['last_season'] == 2023, 'domestic_competition_id'].value_counts()
# Out:
# domestic_competition_id
# TR1     20
# IT1     20
# GB1     20
# ES1     20
# L1      18
# PO1     18
# FR1     18
# NL1     18
# RU1     16
# BE1     16
# UKR1    16
# GR1     14
# DK1     12
# SC1     12
# Name: count, dtype: int64

# %%
club_still_active = new_club.loc[new_club['last_season'] == 2023] 
club_still_active['domestic_competition_id'].value_counts().plot(kind='bar', 
                                                                 title = 'Count Club for every domestic competition still active',
                                                                 color = 'skyblue',
                                                                 edgecolor='black' )
# Out:
# <Axes: title={'center': 'Count Club for every domestic competition still active'}, xlabel='domestic_competition_id'>

# %%
ax = new_club['last_season'].value_counts().plot(kind='bar', 
                                                 title = 'last season counts for club active',
                                                 color = 'skyblue',
                                                 edgecolor='black')
ax.set_xlabel('last season year')
ax.set_ylabel('number of club still active')
# Out:
# Text(0, 0.5, 'number of club still active')

# %%
new_club['average_age'].plot(kind='hist',
                             bins= 20,
                             title = 'Distribution average_age for every club',
                             color = 'skyblue',
                             edgecolor='black')
# Out:
# <Axes: title={'center': 'Distribution average_age for every club'}, ylabel='Frequency'>

# %%
sns.boxplot(data = new_club['average_age'],
            color = 'skyblue')
# Out:
# <Axes: ylabel='average_age'>

# %%
new_club.sort_values(by='average_age').head(5) #outliers
# Out:
#      club_id      club_code           name domestic_competition_id  \
# 71     18105       pfk-lviv       PFK Lviv                    UKR1
# 122     2323       orduspor       Orduspor                     TR1
# 200    19771    akhisarspor    Akhisarspor                     TR1
# 150       20      bursaspor      Bursaspor                     TR1
# 121    20698  balikesirspor  Balikesirspor                     TR1
#
#      squad_size  average_age  foreigners_number  foreigners_percentage  \
# 71            3         18.3                  0              45.227968
# 122           3         20.0                  0              45.227968
# 200          14         21.0                  0              45.227968
# 150          26         21.4                  0              45.227968
# 121          22         22.0                  1               4.500000
#
#      national_team_players                        stadium_name  stadium_seats  \
# 71                       0                        Stadion SKIF           3742
# 122                      0                    19 Eylül Stadyum          11024
# 200                      0          Spor Toto Akhisar Stadyumu          12139
# 150                      0  Bursa Büyükşehir Belediye Stadyumu          43361
# 121                      0                   Balıkesir Atatürk          15800
#
#     net_transfer_record  last_season
# 71                  +-0         2022
# 122                 +-0         2012
# 200                +€5k         2018
# 150                 +-0         2018
# 121                 +-0         2014

# %%
new_club.sort_values(by='average_age').tail(5) #outliers
# Out:
#      club_id        club_code                              name  \
# 113     1050    fc-villarreal  Villarreal Club de Fútbol S.A.D.
# 272     2687         fc-cadiz        Cádiz Club de Fútbol S.A.D
# 64        13  atletico-madrid    Club Atlético de Madrid S.A.D.
# 206      367   rayo-vallecano   Rayo Vallecano de Madrid S.A.D.
# 276     3209       pendikspor                        Pendikspor
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 113                     ES1          24         29.1                  9
# 272                     ES1          28         29.1                  8
# 64                      ES1          24         29.3                 14
# 206                     ES1          24         29.3                 11
# 276                     TR1          27         29.7                 13
#
#      foreigners_percentage  national_team_players  \
# 113                   37.5                      7
# 272                   28.6                      2
# 64                    58.3                     15
# 206                   45.8                      6
# 276                   48.1                      3
#
#                     stadium_name  stadium_seats net_transfer_record  \
# 113                  La Cerámica          23500            +€97.00m
# 272             Nuevo Mirandilla          21094             +€3.50m
# 64         Civitas Metropolitano          67829            +€57.30m
# 206  Campo de Fútbol de Vallecas          15105            €-11.60m
# 276                 Pendik Stadı           2500             €-3.10m
#
#      last_season
# 113         2023
# 272         2023
# 64          2023
# 206         2023
# 276         2023

# %%
ax = new_club['foreigners_number'].plot(kind='hist', 
                                        bins = 20, 
                                        title = 'Distribution number of foreigners players',
                                        color = 'skyblue',
                                        edgecolor = 'black')
ax.set_xlabel('Foreigners player')
# Out:
# Text(0.5, 0, 'Foreigners player')

# %%
new_club['foreigners_number'].mean()
# Out:
# 10.98356807511737

# %%
sns.boxplot(data = new_club['foreigners_number'],
            color = 'skyblue')
# Out:
# <Axes: ylabel='foreigners_number'>

# %%
ax = new_club['stadium_seats'].plot(kind='hist', 
                               bins = 25,
                               title = 'Distribution for seats in stadium for every clubs',
                               color= 'skyblue',
                               edgecolor='black')
ax.set_xlabel('stadium seats')
# Out:
# Text(0.5, 0, 'stadium seats')

# %%
sns.boxplot(data = new_club['stadium_seats'],
            color = 'skyblue')
# Out:
# <Axes: ylabel='stadium_seats'>

# %%
new_club.sort_values(by='stadium_seats').head(5) #outliers
# Out:
#      club_id          club_code                        name  \
# 409    30120        ae-kifisias    Athlitiki Enosi Kifisias
# 338    61825           fk-minaj                    FK Minaj
# 254     2700  anzhi-makhachkala  Anzhi Makhachkala ( -2022)
# 225    23611    olimpik-donetsk             Olimpik Donetsk
# 129    49364   ingulets-petrove            Ingulets Petrove
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 409                     GR1          28    27.300000                 14
# 338                    UKR1          27    25.500000                  1
# 254                     RU1           0    25.704639                  0
# 225                    UKR1           0    25.704639                  0
# 129                    UKR1          23    25.700000                  2
#
#      foreigners_percentage  national_team_players  \
# 409              50.000000                      2
# 338               3.700000                      0
# 254              45.227968                      0
# 225              45.227968                      0
# 129               8.300000                      0
#
#                                     stadium_name  stadium_seats  \
# 409   Gipedo Kesarianis "Michalis Kritikopoulos"              0
# 338                                  Minaj-Arena           1312
# 254  RDYuSSh MinObrNauki RD Politekh Makhachkala           1600
# 225                      NTK im. B. M. Bannikova           1678
# 129                             Stadion Ingulets           1720
#
#     net_transfer_record  last_season
# 409                 +-0         2023
# 338               €-60k         2023
# 254                 +-0         2018
# 225                 +-0         2020
# 129              +€100k         2022

# %%
new_club.sort_values(by='stadium_seats').tail(5) #outliers
# Out:
#      club_id          club_code                                        name  \
# 79        46      inter-mailand  Football Club Internazionale Milano S.p.A.
# 309        5         ac-mailand                   Associazione Calcio Milan
# 174     1186     torpedo-moskau                              Torpedo Moscow
# 281      418        real-madrid                  Real Madrid Club de Fútbol
# 178       16  borussia-dortmund                           Borussia Dortmund
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 79                      IT1          25         29.0                 16
# 309                     IT1          29         26.3                 22
# 174                     RU1          28         25.6                  6
# 281                     ES1          23         27.7                 15
# 178                      L1          28         26.0                 13
#
#      foreigners_percentage  national_team_players       stadium_name  \
# 79                    64.0                     19    Giuseppe Meazza
# 309                   75.9                     15    Giuseppe Meazza
# 174                   23.1                      3   Luzhniki Stadium
# 281                   65.2                     19  Santiago Bernabéu
# 178                   46.4                     17  SIGNAL IDUNA PARK
#
#      stadium_seats net_transfer_record  last_season
# 79           75923            +€65.20m         2023
# 309          75923            €-47.40m         2023
# 174          81000             €-2.05m         2022
# 281          81044           €-122.50m         2023
# 178          81365            +€47.85m         2023

# %%
ax = new_club['foreigners_percentage'].plot(kind='hist',
                                       bins = 20,
                                       title = 'Distribution for foreigners percentage for every club',
                                       color = 'skyblue',
                                       edgecolor = 'black')
ax.set_xlabel('foreigners percentage')
# Out:
# Text(0.5, 0, 'foreigners percentage')

# %%
sns.boxplot(data = new_club['foreigners_percentage'] ,
            color = 'skyblue')
# Out:
# <Axes: ylabel='foreigners_percentage'>

# %%
new_club.sort_values(by='foreigners_percentage').head(5) #outliers
# Out:
#      club_id        club_code                  name domestic_competition_id  \
# 167      825    eskisehirspor         Eskisehirspor                     TR1
# 229     2944       ankaraspor            Ankaraspor                     TR1
# 338    61825         fk-minaj              FK Minaj                    UKR1
# 234      621  athletic-bilbao  Athletic Club Bilbao                     ES1
# 102    39097   fk-obolon-kiew        FK Obolon Kyiv                    UKR1
#
#      squad_size  average_age  foreigners_number  foreigners_percentage  \
# 167          41         23.9                  1                    2.4
# 229          30         23.8                  1                    3.3
# 338          27         25.5                  1                    3.7
# 234          25         27.7                  1                    4.0
# 102          23         27.3                  1                    4.3
#
#      national_team_players            stadium_name  stadium_seats  \
# 167                      0  Eskişehir Yeni Stadyum          34930
# 229                      0           Osmanlı Stadı          19626
# 338                      0             Minaj-Arena           1312
# 234                      4               San Mamés          53289
# 102                      0            Obolon-Arena           5103
#
#     net_transfer_record  last_season
# 167                 +-0         2015
# 229                 +-0         2017
# 338               €-60k         2023
# 234                 +-0         2023
# 102               €-80k         2023

# %%
new_club.sort_values(by='stadium_seats').tail(5) #outliers
# Out:
#      club_id          club_code                                        name  \
# 79        46      inter-mailand  Football Club Internazionale Milano S.p.A.
# 309        5         ac-mailand                   Associazione Calcio Milan
# 174     1186     torpedo-moskau                              Torpedo Moscow
# 281      418        real-madrid                  Real Madrid Club de Fútbol
# 178       16  borussia-dortmund                           Borussia Dortmund
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 79                      IT1          25         29.0                 16
# 309                     IT1          29         26.3                 22
# 174                     RU1          28         25.6                  6
# 281                     ES1          23         27.7                 15
# 178                      L1          28         26.0                 13
#
#      foreigners_percentage  national_team_players       stadium_name  \
# 79                    64.0                     19    Giuseppe Meazza
# 309                   75.9                     15    Giuseppe Meazza
# 174                   23.1                      3   Luzhniki Stadium
# 281                   65.2                     19  Santiago Bernabéu
# 178                   46.4                     17  SIGNAL IDUNA PARK
#
#      stadium_seats net_transfer_record  last_season
# 79           75923            +€65.20m         2023
# 309          75923            €-47.40m         2023
# 174          81000             €-2.05m         2022
# 281          81044           €-122.50m         2023
# 178          81365            +€47.85m         2023

# %%
new_club['national_team_players'].plot(kind='hist',
                                     bins = 20,
                                     title = 'Distribution for national percentage for every club',
                                     color = 'skyblue',
                                     edgecolor = 'black')
# Out:
# <Axes: title={'center': 'Distribution for national percentage for every club'}, ylabel='Frequency'>

# %%
sns.boxplot(data = new_club['national_team_players'],
            color = 'skyblue')
# Out:
# <Axes: ylabel='national_team_players'>

# %%
new_club.sort_values(by='national_team_players').head(5) #outliers
# Out:
#      club_id         club_code                     name  \
# 101     3609   rotor-volgograd          Rotor Volgograd
# 130      498       ksc-lokeren     KSC Lokeren (- 2020)
# 129    49364  ingulets-petrove         Ingulets Petrove
# 126     3691         tom-tomsk                Tom Tomsk
# 298     2439   kuban-krasnodar  Kuban Krasnodar (-2018)
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 101                     RU1          27    23.900000                  2
# 130                     BE1           0    25.704639                  0
# 129                    UKR1          23    25.700000                  2
# 126                     RU1           0    25.704639                  0
# 298                     RU1           0    25.704639                  0
#
#      foreigners_percentage  national_team_players      stadium_name  \
# 101               7.400000                      0   Volgograd Arena
# 130              45.227968                      0     Daknamstadion
# 129               8.300000                      0  Stadion Ingulets
# 126              45.227968                      0              Trud
# 298              45.227968                      0     Kuban Stadium
#
#      stadium_seats net_transfer_record  last_season
# 101          45568               €-13k         2020
# 130          12000                 +-0         2018
# 129           1720              +€100k         2022
# 126          10028                 +-0         2016
# 298          31654                 +-0         2015

# %%
new_club.sort_values(by='national_team_players').tail(5) #outliers
# Out:
#      club_id          club_code                             name  \
# 321       11         fc-arsenal            Arsenal Football Club
# 135      703  nottingham-forest  Nottingham Forest Football Club
# 329      281    manchester-city    Manchester City Football Club
# 242      985  manchester-united  Manchester United Football Club
# 4        148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 321                     GB1          25         25.8                 18
# 135                     GB1          32         27.1                 27
# 329                     GB1          24         27.2                 17
# 242                     GB1          31         26.4                 22
# 4                       GB1          29         26.2                 21
#
#      foreigners_percentage  national_team_players               stadium_name  \
# 321                   72.0                     20           Emirates Stadium
# 135                   84.4                     20            The City Ground
# 329                   70.8                     21             Etihad Stadium
# 242                   71.0                     22               Old Trafford
# 4                     72.4                     22  Tottenham Hotspur Stadium
#
#      stadium_seats net_transfer_record  last_season
# 321          60704           €-167.04m         2023
# 135          30445            €-57.23m         2023
# 329          55017           €-126.60m         2023
# 242          74879           €-148.06m         2023
# 4            62062           €-130.40m         2023

# %%
new_club['squad_size'].plot(kind ="hist",
                            bins = 20,
                            title = 'Distribution for squad size for every club',
                            color = 'skyblue',
                            edgecolor = 'black')
# Out:
# <Axes: title={'center': 'Distribution for squad size for every club'}, ylabel='Frequency'>

# %%
sns.boxplot(data = new_club['squad_size'],
            color = 'skyblue')
# Out:
# <Axes: ylabel='squad_size'>

# %%
new_club.sort_values(by='squad_size').head(20) #outliers
# Out:
#      club_id              club_code                             name  \
# 130      498            ksc-lokeren             KSC Lokeren (- 2020)
# 345      862          chievo-verona                    Chievo Verona
# 341     6894    kayseri-erciyesspor              Kayseri Erciyesspor
# 91     16239        desna-chernigiv                  Desna Chernigiv
# 202    29228   royal-excel-mouscron     Royal Excel Mouscron (-2022)
# 203     3216      mersin-idmanyurdu             Mersin Talimyurdu SK
# 210    40426               fk-tosno                 FC Tosno (-2018)
# 326     2227  sk-tavriya-simferopol  SK Tavriya Simferopol ( - 2022)
# 325      204              lierse-sk               Lierse SK (- 2018)
# 25      6996       goverla-uzhgorod        Goverla Uzhgorod (- 2016)
# 38      2477           karpaty-lviv             Karpaty Lviv (-2021)
# 225    23611        olimpik-donetsk                  Olimpik Donetsk
# 254     2700      anzhi-makhachkala       Anzhi Makhachkala ( -2022)
# 68      1411              raec-mons               RAEC Mons (- 2015)
# 307     4482            volyn-lutsk                      Volyn Lutsk
# 299     2703    spartak-vladikavkaz      Spartak Vladikavkaz (-2020)
# 298     2439        kuban-krasnodar          Kuban Krasnodar (-2018)
# 53       566           beerschot-ac                     Beerschot AC
# 268    16245          fk-sevastopol           FK Sevastopol (- 2014)
# 221     1506   kardemir-karabukspor             Kardemir Karabükspor
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 130                     BE1           0    25.704639                  0
# 345                     IT1           0    25.704639                  0
# 341                     TR1           0    25.704639                  0
# 91                     UKR1           0    25.704639                  0
# 202                     BE1           0    25.704639                  0
# 203                     TR1           0    25.704639                  0
# 210                     RU1           0    25.704639                  0
# 326                    UKR1           0    25.704639                  0
# 325                     BE1           0    25.704639                  0
# 25                     UKR1           0    25.704639                  0
# 38                     UKR1           0    25.704639                  0
# 225                    UKR1           0    25.704639                  0
# 254                     RU1           0    25.704639                  0
# 68                      BE1           0    25.704639                  0
# 307                    UKR1           0    25.704639                  0
# 299                     RU1           0    25.704639                  0
# 298                     RU1           0    25.704639                  0
# 53                      BE1           0    25.704639                  0
# 268                    UKR1           0    25.704639                  0
# 221                     TR1           0    25.704639                  0
#
#      foreigners_percentage  national_team_players  \
# 130              45.227968                      0
# 345              45.227968                      0
# 341              45.227968                      0
# 91               45.227968                      0
# 202              45.227968                      0
# 203              45.227968                      0
# 210              45.227968                      0
# 326              45.227968                      0
# 325              45.227968                      0
# 25               45.227968                      0
# 38               45.227968                      0
# 225              45.227968                      0
# 254              45.227968                      0
# 68               45.227968                      0
# 307              45.227968                      0
# 299              45.227968                      0
# 298              45.227968                      0
# 53               45.227968                      0
# 268              45.227968                      0
# 221              45.227968                      0
#
#                                      stadium_name  stadium_seats  \
# 130                                 Daknamstadion          12000
# 345                         Marcantonio Bentegodi          31045
# 341  Kayseri Atatürk Spor Kompleksi Yan Açık Saha           2000
# 91                    Stadion im. Yuriya Gagarina          12060
# 202                                  Le Canonnier          10830
# 203                               Mersin Stadyumu          25000
# 210                                     Petrovsky          20985
# 326                                  RS Lokomotiv          19978
# 325                   Herman Vanderpoortenstadion          14538
# 25                                       Avangard          10640
# 38                                Stadion Ukraina          28051
# 225                       NTK im. B. M. Bannikova           1678
# 254   RDYuSSh MinObrNauki RD Politekh Makhachkala           1600
# 68                         Stade Charles Tondreau          12662
# 307                              Stadion Avangard          12080
# 299                    Republican Stadium Spartak          32464
# 298                                 Kuban Stadium          31654
# 53                              Olympisch Stadion          12771
# 268                                 SK Sevastopol           5826
# 221                        Dr. Necmettin Şeyhoğlu          12400
#
#     net_transfer_record  last_season
# 130                 +-0         2018
# 345                 +-0         2018
# 341                 +-0         2014
# 91                  +-0         2021
# 202               +€40k         2020
# 203                 +-0         2015
# 210                 +-0         2017
# 326                 +-0         2013
# 325                 +-0         2014
# 25                  +-0         2015
# 38                  +-0         2019
# 225                 +-0         2020
# 254                 +-0         2018
# 68                  +-0         2013
# 307                 +-0         2016
# 299                 +-0         2012
# 298                 +-0         2015
# 53                  +-0         2012
# 268                 +-0         2013
# 221                 +-0         2017

# %%
new_club.sort_values(by='squad_size').tail(5) #outliers
# Out:
#      club_id            club_code                            name  \
# 152       24  eintracht-frankfurt  Eintracht Frankfurt Fußball AG
# 322      126      caykur-rizespor          Çaykur Rizespor Kulübü
# 389       44           hertha-bsc                      Hertha BSC
# 183     2423       cd-santa-clara                  CD Santa Clara
# 167      825        eskisehirspor                   Eskisehirspor
#
#     domestic_competition_id  squad_size  average_age  foreigners_number  \
# 152                      L1          36         24.6                 20
# 322                     TR1          36         24.6                 18
# 389                      L1          36         24.1                 14
# 183                     PO1          38         25.4                 20
# 167                     TR1          41         23.9                  1
#
#      foreigners_percentage  national_team_players            stadium_name  \
# 152                   55.6                      9      Deutsche Bank Park
# 322                   50.0                      6             Çaykur Didi
# 389                   38.9                      7   Olympiastadion Berlin
# 183                   52.6                      2   Estádio de São Miguel
# 167                    2.4                      0  Eskişehir Yeni Stadyum
#
#      stadium_seats net_transfer_record  last_season
# 152          56500            +€85.85m         2023
# 322          15332             €-3.41m         2023
# 389          74667             +€6.70m         2022
# 183          12500                 +-0         2022
# 167          34930                 +-0         2015

# %%
new_club.loc[new_club['squad_size'] == 0].value_counts().sum()
# Out:
# 38

# %%
club_without_squad = new_club.loc[~(new_club['squad_size'] == 0)]
club_without_squad.loc[club_without_squad['squad_size'] == 0].value_counts().sum()
# Out:
# 0

# %%
club_without_squad['squad_size'].describe()
# Out:
# count    388.000000
# mean      26.793814
# std        4.602411
# min        3.000000
# 25%       25.000000
# 50%       27.000000
# 75%       29.000000
# max       41.000000
# Name: squad_size, dtype: float64

# %%
club_without_squad['squad_size'].plot(kind = 'hist',
                                      bins = 20,
                                      title = 'Distribution for squad size without zero squad size',
                                      color = 'skyblue',
                                      edgecolor = 'black')
# Out:
# <Axes: title={'center': 'Distribution for squad size without zero squad size'}, ylabel='Frequency'>

# %%
new_club.groupby('domestic_competition_id')['stadium_seats'].agg(['min', 'max', 'mean']).plot(kind ="bar")
# Out:
# <Axes: xlabel='domestic_competition_id'>

# %%
club_without_squad.groupby('domestic_competition_id')['squad_size'].agg(['min', 'max', 'mean']).plot(kind ="bar")
# Out:
# <Axes: xlabel='domestic_competition_id'>

# %%
new_club.groupby('domestic_competition_id')['foreigners_number'].agg(['min', 'max', 'mean']).plot(kind ="bar")
# Out:
# <Axes: xlabel='domestic_competition_id'>

# %%
new_club.groupby('domestic_competition_id')['foreigners_percentage'].agg(['min', 'max', 'mean']).plot(kind ="bar")
# Out:
# <Axes: xlabel='domestic_competition_id'>

# %%
new_club[['average_age','foreigners_percentage', 'foreigners_number', 'national_team_players', 'squad_size', 'stadium_seats']].corr()
# Out:
#                        average_age  foreigners_percentage  foreigners_number  \
# average_age               1.000000               0.121422           0.131300
# foreigners_percentage     0.121422               1.000000           0.784096
# foreigners_number         0.131300               0.784096           1.000000
# national_team_players     0.171978               0.576624           0.658453
# squad_size                0.032204               0.055986           0.622954
# stadium_seats             0.130657               0.198059           0.248135
#
#                        national_team_players  squad_size  stadium_seats
# average_age                         0.171978    0.032204       0.130657
# foreigners_percentage               0.576624    0.055986       0.198059
# foreigners_number                   0.658453    0.622954       0.248135
# national_team_players               1.000000    0.340089       0.586494
# squad_size                          0.340089    1.000000       0.172214
# stadium_seats                       0.586494    0.172214       1.000000

# %%
sns.heatmap(new_club[['average_age','foreigners_percentage', 'foreigners_number', 'national_team_players', 'squad_size', 'stadium_seats']].corr(), annot=True)
# Out:
# <Axes: >

# %%
new_club.plot(kind = 'scatter', 
              x = 'foreigners_percentage',
              y = 'foreigners_percentage', 
              title = 'foreigners_number vs foreigners_percentage')
plt.show()
